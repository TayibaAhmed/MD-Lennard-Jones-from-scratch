# %%
# MD (Molecular Dynamics) is based on classical mechanics.
# particles are treated as classical point masses.
# there is no random or stochastic component so you will always find the same soln. every time you run.

# depending on the positions of the point particles, you associate a certain potential energy with then.
# then each pair of particles is associated with an interaction. 
# sum the contributions of energy of all pairs (based on distance) to find the total potential energy.

# electrostatic/VWF interaction. 
# bond angle deviation leading to driving force to get back to equilibrium angle also exists.

# forces are found by taking gradient of electrical potential.
# F_vec(i,x) = - partial( U(r_vec_1, r_vc_2, ...) ) / partial( x_i ) = - partial( U(x_1,y_1,z_1,x_2,y_2,z_2, ...) ) / partial(x_i)
# F_vec(i,y) = - partial(U) / partial(y_i) similarly can be converted.

# each pair interaction then givees you contribution of force on the particle.
# sum of pair interactions gives overall force on the particle.

# 2 contributions (repulsive - bond repulsion / attractive - VWF)
# lennard jones potential ka U(r) / r graph aur uss ki defining properties yaad kar lo.
# the system will always try to drive the particle to the local potential minimum (2^(1/6)*sigma ya iss tarah ka kuch)
# LJ pair potential has its form due to computational convenience (but the power itself does not have specific theoretical background)

# radial force magnitude is found by taking derivative of potential w.r.t. distance.
# individual gradients to x, y, z ,,, r =sqrt(x^2 + y^2 + z^2)
# find out F_x, F_y, F_z using chain rule.
# F_x = - du/dx = -du/dr * dr/dx
# for r you can use pythagoras' and you find out it's actually a unit vector.

# unit vector = r_vec / r
# everything is just in unit vector of r. 
# r_vec(x, y, z) => r^2 = x^2 + y^2 + z^2
# => r = sqrt(x^2 + y^2 + z^2).

# a^nu = exp(nu*ln(a))
